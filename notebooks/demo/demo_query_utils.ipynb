# %%
from query_utils import connect_catalog

# %%
con = connect_catalog()
# Out:
# ✅ 已成功连接并挂载 Catalog (只读): /Users/mu/Desktop/the-nomad-data-stack/.duckdb/catalog.duckdb

# %%
con.execute("SHOW ALL TABLES;").df()
# Out:
#   database        schema                        name  \
# 0  catalog  catalog_meta           schema_migrations
# 1  catalog           ods  ods_etf_universe_whitelist
# 2  catalog           ods           ods_fund_etf_spot
#
#                               column_names  \
# 0         [filename, checksum, applied_at]
# 1  [symbol, name, enabled, trade_date, dt]
# 2   [symbol, name, amount, trade_date, dt]
#
#                                  column_types  temporary
# 0               [VARCHAR, VARCHAR, TIMESTAMP]      False
# 1  [VARCHAR, VARCHAR, INTEGER, DATE, VARCHAR]      False
# 2   [VARCHAR, VARCHAR, DOUBLE, DATE, VARCHAR]      False

# %%
con.sql("select * from ods.ods_etf_universe_whitelist").df()
# Out:
#    symbol      name  enabled trade_date          dt
# 0  513770  港股互联网ETF        1 2025-12-22  2025-12-22
