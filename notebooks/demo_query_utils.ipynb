# %%
from query_utils import connect_catalog

# %%
con = connect_catalog()
# Out:
# ✅ 已成功连接并切换至 Catalog: C:\Users\mu\Desktop\the-nomad-data-stack\.duckdb\catalog.duckdb

# %%
con.execute("SHOW ALL TABLES;").df()
# Out:
#   database        schema                        name  \
# 0  catalog  catalog_meta           schema_migrations
# 1  catalog           ods  ods_etf_universe_whitelist
# 2  catalog           ods        ods_fund_etf_history
# 3  catalog           ods           ods_fund_etf_spot
#
#                                         column_names  \
# 0                   [filename, checksum, applied_at]
# 1            [symbol, name, enabled, trade_date, dt]
# 2  [symbol, trade_date, open, high, low, close, v...
# 3             [symbol, name, amount, trade_date, dt]
#
#                                         column_types  temporary
# 0                      [VARCHAR, VARCHAR, TIMESTAMP]      False
# 1         [VARCHAR, VARCHAR, INTEGER, DATE, VARCHAR]      False
# 2  [VARCHAR, DATE, DOUBLE, DOUBLE, DOUBLE, DOUBLE...      False
# 3          [VARCHAR, VARCHAR, DOUBLE, DATE, VARCHAR]      False

# %%
con.sql("select * from ods.ods_fund_etf_history").df()
# Out:
#    symbol trade_date   open   high    low  close      volume       amount  \
# 0  513770 2025-12-22  0.530  0.535  0.529  0.530  10897266.0  579133217.0
# 1  510210 2025-12-22  0.975  0.982  0.975  0.981   3677193.0  360431216.0
#
#    amplitude  change_percent  change_amount  turnover_rate          dt
# 0       1.13            0.19          0.001           4.65  2025-12-22
# 1       0.72            0.62          0.006           5.90  2025-12-22
