# %%
from query_utils import connect_catalog
# Out:
#   Cell In[9], line 1
#     from ..\query_utils import connect_catalog
#             ^
# SyntaxError: unexpected character after line continuation character

# %%
con = connect_catalog()

# %%
con.execute("SHOW ALL TABLES;").df()

# %%
con.sql("select * from ods.ods_etf_universe_whitelist").df()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 con.sql("select * from ods.ods_etf_universe_whitelist").df()
#
# NameError: name 'con' is not defined
